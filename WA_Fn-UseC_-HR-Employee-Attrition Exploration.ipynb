# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # View the age distribution of the employees

# %%
plt.figure(figsize=(20,5))
sns.barplot(df['Age'].value_counts())
plt.title('Age distribution of the employees')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # explore data for Attrition by Age

# %%
plt.figure(figsize=(20,5))
sns.countplot(x=df['Age'],hue=df['Attrition'])
plt.title('explore data for Attrition by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # explore data for Left employees breakdown

# %%
plt.figure(figsize=(20,5))
plt.pie(df['Attrition'].value_counts(), labels = ('No','Yes'),autopct = '%1.2f%%',explode = (0.1,0))
plt.title('explore data for Left employees breakdown')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Explore data for Education Field distribution

# %%
plt.figure(figsize=(20,5))
plt.pie(df['EducationField'].value_counts(),autopct='%1.1f%%',labels=tuple(dict(df['EducationField'].value_counts()).keys()))
plt.title('Explore data for Education Field distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # explore data for Marital Status

# %%
plt.figure(figsize=(20,5))
sns.barplot(df['MaritalStatus'].value_counts())
plt.title('explore data for Marital Status')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
